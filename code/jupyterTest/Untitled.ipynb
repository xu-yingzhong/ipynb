# %% [markdown]
# $x^{2}+y^{2}=z^{2}$ $$ \frac{2}{3}$$

# %%
x = 2
y = 2
z = x**2 + y**2
print(z)
# Out:
# 8

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook
a = np.arange(10)
b = a**2
plt.plot(a,b)
# Out:
# <img src="data:image/png;base64,..." width="432">
